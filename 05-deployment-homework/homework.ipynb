# %% [markdown]
# ## Homework
#
# > Note: sometimes your answer doesn't match one of the options exactly.
# > That's fine.
# > Select the option that's closest to your solution.
# > If it's exactly in between two options, select the higher value.
#
# We recommend using python 3.12 or 3.13 in this homework.
#
# In this homework, we're going to continue working with the lead scoring dataset. You don't need the dataset: we will provide the model for you.

# %% [markdown]
# ## Question 1
#
# * Install `uv`
# * What's the version of uv you installed?
# * Use `--version` to find out

# %%
# !uv --version
# Out:
# uv 0.9.5

# %% [markdown]
# ## Initialize an empty uv project
#
# You should create an empty folder for homework
# and do it there.

# %% [markdown]
# ## Question 2
#
# * Use uv to install Scikit-Learn version 1.6.1
# * What's the first hash for Scikit-Learn you get in the lock file?
# * Include the entire string starting with sha256:, don't include quotes

# %% [markdown]
# sha256:b4fc2525eca2c69a59260f583c56a7557c6ccdf8deafdba6e060f94c1c59738e

# %% [markdown]
# ## Models
#
# We have prepared a pipeline with a dictionary vectorizer and a model.
#
# It was trained (roughly) using this code:
#
# ```python
# categorical = ['lead_source']
# numeric = ['number_of_courses_viewed', 'annual_income']
#
# df[categorical] = df[categorical].fillna('NA')
# df[numeric] = df[numeric].fillna(0)
#
# train_dict = df[categorical + numeric].to_dict(orient='records')
#
# pipeline = make_pipeline(
#     DictVectorizer(),
#     LogisticRegression(solver='liblinear')
# )
#
# pipeline.fit(train_dict, y_train)
# ```
#
# > **Note**: You don't need to train the model. This code is just for your reference.
#
# And then saved with Pickle. Download it [here](https://github.com/DataTalksClub/machine-learning-zoomcamp/tree/master/cohorts/2025/05-deployment/pipeline_v1.bin).
#
# With `wget`:
#
# ```bash
# wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# ```

# %%
# !wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Out:
# --2025-10-27 21:45:25--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin [following]
# --2025-10-27 21:45:26--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1300 (1.3K) [application/octet-stream]
# Saving to: ‘pipeline_v1.bin’
#
# pipeline_v1.bin     100%[===================>]   1.27K  --.-KB/s    in 0s
#
# 2025-10-27 21:45:26 (79.7 MB/s) - ‘pipeline_v1.bin’ saved [1300/1300]

# %% [markdown]
# ## Question 3
#
# Let's use the model!
#
# * Write a script for loading the pipeline with pickle
# * Score this record:
#
# ```json
# {
#     "lead_source": "paid_ads",
#     "number_of_courses_viewed": 2,
#     "annual_income": 79276.0
# }
# ```
#
# What's the probability that this lead will convert?
#
# * 0.333
# * 0.533
# * 0.733
# * 0.933
#
# If you're getting errors when unpickling the files, check their checksum:
#
# ```bash
# $ md5sum pipeline_v1.bin
# 7d17d2e4dfbaf1e408e1a62e6e880d49 *pipeline_v1.bin
# ```

# %%
import pickle

# %%
with open('pipeline_v1.bin', 'rb') as f_in:
    pipeline = pickle.load(f_in)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator DictVectorizer from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def predict_single(record):
    result = pipeline.predict_proba(record)[0, 1]
    return float(result)

# %%
record = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

predict_single(record)
# Out:
# 0.5336072702798061

# %% [markdown]
# ## Question 4
#
# Now let's serve this model as a web service
#
# * Install FastAPI
# * Write FastAPI code for serving the model
# * Now score this client using `requests`:
#
# ```python
# url = "YOUR_URL"
# client = {
#     "lead_source": "organic_search",
#     "number_of_courses_viewed": 4,
#     "annual_income": 80304.0
# }
# requests.post(url, json=client).json()
# ```
#
# What's the probability that this client will get a subscription?
#
# * 0.334
# * 0.534
# * 0.734
# * 0.934

# %%
import requests

# %%
url = "http://localhost:9696/predict"
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
requests.post(url, json=client).json()
# Out:
# {'probability': 0.5340417283801275}

# %% [markdown]
# ## Docker
#
# Install [Docker](https://github.com/DataTalksClub/machine-learning-zoomcamp/blob/master/05-deployment/06-docker.md).
# We will use it for the next two questions.
#
# For these questions, we prepared a base image: `agrigorev/zoomcamp-model:2025`.
# You'll need to use it (see Question 5 for an example).
#
# This image is based on `3.13.5-slim-bookworm` and has
# a pipeline with logistic regression (a different one)
# as well a dictionary vectorizer inside.
#
# This is how the Dockerfile for this image looks like:
#
# ```docker
# FROM python:3.13.5-slim-bookworm
# WORKDIR /code
# COPY pipeline_v2.bin .
# ```
#
# We already built it and then pushed it to [`agrigorev/zoomcamp-model:2025`](https://hub.docker.com/r/agrigorev/zoomcamp-model).
#
# > **Note**: You don't need to build this docker image, it's just for your reference.

# %% [markdown]
# ## Question 5
#
# Download the base image `agrigorev/zoomcamp-model:2025`. You can easily make it by using [docker pull](https://docs.docker.com/engine/reference/commandline/pull/) command.
#
# So what's the size of this base image?
#
# * 45 MB
# * 121 MB
# * 245 MB
# * 330 MB
#
# You can get this information when running `docker images` - it'll be in the "SIZE" column.

# %%
# !docker pull agrigorev/zoomcamp-model:2025
# Out:
# 2025: Pulling from agrigorev/zoomcamp-model
#
# 2667830b: Already exists
# 1082f6f0: Already exists
# f5177ae2: Already exists
# 357cf7a1: Already exists
# 2b9cc6ee: Pulling fs layer
# Digest: sha256:14d79fde0bbf078eb18c99c2bd007205917b758ec11060b2994963a1e485c2ae
# Status: Downloaded newer image for agrigorev/zoomcamp-model:2025
# docker.io/agrigorev/zoomcamp-model:2025

# %%
# !docker images
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED      SIZE
# churn-prediction           latest    9a5de19646e2   2 days ago   491MB
# agrigorev/zoomcamp-model   2025      4a9ecc576ae9   6 days ago   121MB

# %% [markdown]
# ## Dockerfile
#
# Now create your own `Dockerfile` based on the image we prepared.
#
# It should start like that:
#
# ```docker
# FROM agrigorev/zoomcamp-model:2025
# # add your stuff here
# ```
#
# Now complete it:
#
# * Install all the dependencies from pyproject.toml
# * Copy your FastAPI script
# * Run it with uvicorn
#
# After that, you can build your docker image.

# %% [markdown]
# ## Question 6
#
# Let's run your docker container!
#
# After running it, score this client once again:
#
# ```python
# url = "YOUR_URL"
# client = {
#     "lead_source": "organic_search",
#     "number_of_courses_viewed": 4,
#     "annual_income": 80304.0
# }
# requests.post(url, json=client).json()
# ```
#
# What's the probability that this lead will convert?
#
# * 0.39
# * 0.59
# * 0.79
# * 0.99

# %%
# !docker build -t score-prediction .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.2s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
# [+] Building 0.2s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.2s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
# [+] Building 0.4s (3/4)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.3s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
# [+] Building 0.5s (3/4)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.5s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
# [+] Building 0.7s (3/4)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.6s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
# [+] Building 0.7s (4/4)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
# [+] Building 0.9s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.2s
# [+] Building 1.1s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.3s
# [+] Building 1.2s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.5s
# [+] Building 1.4s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.6s
# [+] Building 1.5s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.8s
# [+] Building 1.7s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   0.9s
# [+] Building 1.8s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.1s
# [+] Building 2.0s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.2s
# [+] Building 2.1s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.4s
# [+] Building 2.3s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.5s
# [+] Building 2.4s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.7s
# [+] Building 2.6s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   1.8s
# [+] Building 2.7s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.0s
# [+] Building 2.9s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.1s
# [+] Building 3.0s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.3s
# [+] Building 3.2s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.4s
# [+] Building 3.3s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.6s
# [+] Building 3.5s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.7s
# [+] Building 3.6s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   2.9s
# [+] Building 3.8s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.0s
# [+] Building 3.9s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.2s
# [+] Building 4.1s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.3s
# [+] Building 4.2s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.5s
# [+] Building 4.4s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.6s
# [+] Building 4.5s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.8s
# [+] Building 4.7s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   3.9s
# [+] Building 4.8s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.1s
# [+] Building 5.0s (8/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.2s
# [+] Building 5.0s (9/13)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
# [+] Building 5.3s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.2s
# [+] Building 5.4s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.3s
# [+] Building 5.6s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.5s
# [+] Building 5.7s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.6s
# [+] Building 5.9s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.8s
# [+] Building 6.0s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     0.9s
# [+] Building 6.2s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     1.1s
# [+] Building 6.3s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     1.2s
# [+] Building 6.5s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     1.4s
# [+] Building 6.6s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     1.5s
# [+] Building 6.8s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                     1.7s
# [+] Building 6.9s (11/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
# ...
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.1s
#  => => exporting layers                                                    4.1s
# [+] Building 21.9s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.2s
#  => => exporting layers                                                    4.2s
# [+] Building 22.0s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.4s
#  => => exporting layers                                                    4.4s
# [+] Building 22.2s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.5s
#  => => exporting layers                                                    4.5s
# [+] Building 22.3s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.7s
#  => => exporting layers                                                    4.7s
# [+] Building 22.5s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     4.8s
#  => => exporting layers                                                    4.8s
# [+] Building 22.6s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     5.0s
#  => => exporting layers                                                    5.0s
# [+] Building 22.8s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     5.1s
#  => => exporting layers                                                    5.1s
# [+] Building 22.9s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     5.3s
#  => => exporting layers                                                    5.3s
# [+] Building 22.9s (13/14)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     5.3s
#  => => exporting layers                                                    5.3s
# [+] Building 23.0s (14/14) FINISHED                              docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.38kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.7s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [auth] astral-sh/uv:pull token for ghcr.io                             0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e  0.0s
#  => [stage-0 1/6] FROM docker.io/agrigorev/zoomcamp-model:2025             0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92.38kB                                       0.0s
#  => [stage-0 2/6] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /bin/   4.3s
#  => [stage-0 3/6] WORKDIR /code                                            0.0s
#  => [stage-0 4/6] COPY pyproject.toml uv.lock .python-version ./           0.0s
#  => [stage-0 5/6] RUN uv sync --locked                                    12.5s
#  => [stage-0 6/6] COPY predict.py pipeline_v1.bin ./                       0.1s
#  => exporting to image                                                     5.3s
#  => => exporting layers                                                    5.3s
#  => => writing image sha256:18dc9cb16edb2beb1d54c259bfb35585113e076c2f773  0.0s
#  => => naming to docker.io/library/score-prediction                        0.0s

# %%
# Only for reference.
# !docker run -it --rm -p 9696:9696 score-prediction
# Out:
# docker: Error response from daemon: failed to set up container networking: driver failed programming external connectivity on endpoint hungry_goldstine (cad9600453d520abd024cfdfc2155df756c51af3d98b76bf53ca8d5e228127e5): Bind for 0.0.0.0:9696 failed: port is already allocated
#
# Run 'docker run --help' for more information

# %%
url = "http://localhost:9696/predict"
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
requests.post(url, json=client).json()
# Out:
# {'probability': 0.5340417283801275}
